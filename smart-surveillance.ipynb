# %% [markdown]
# # Smart Surveillance System using YOLOv8 for Person Detection and Tracking

# %% [markdown]
# ## 📌 Problem Statement
#
# ## Develop a smart surveillance system that detects and tracks people in video streams using YOLOv8.

# %% [markdown]
# ## 📌 Methodology
# ## Used YOLOv8 pre-trained model
# ## Applied object detection on video frames
# ## Integrated ByteTrack for tracking

# %% [markdown]
# ## 📌 Results
# ## Successfully detected and tracked multiple people
# ## Each person assigned a unique ID
# ## Real-time performance achieved

# %% [markdown]
# ### Installation

# %%
# !pip install ultralytics

# %% [markdown]
# ### LOAD MODEL

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53acb604-32ee-4b4f-b359-e947385bb520" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53acb604-32ee-4b4f-b359-e947385bb520">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.track(
    source="construction site video.mp4",
    show=True,
    save=True,
    tracker="bytetrack.yaml"
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/207) /content/construction site video.mp4: 384x640 7 persons, 157.4ms
# video 1/1 (frame 2/207) /content/construction site video.mp4: 384x640 6 persons, 145.6ms
# video 1/1 (frame 3/207) /content/construction site video.mp4: 384x640 6 persons, 139.4ms
# video 1/1 (frame 4/207) /content/construction site video.mp4: 384x640 4 persons, 141.9ms
# ...
